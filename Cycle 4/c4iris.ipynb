# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
#1
col=['sepal.length','sepal.width','petal.length','petal.width','variety']
iris=pd.read_csv("iris.csv",names=col)
print("First five rows:")
print(iris.head())
print("Last five rows:")
print(iris.tail())
print("columns")
print(iris.columns)
print("size")
print(iris.size)
print("shape")
print(iris.shape)
print("sample available for each variety:")
print(iris["variety"].value_counts())
print("Describe")
print(iris.describe())
#2
iris=sns.load_dataset('iris')
data_in=pd.DataFrame(iris)
data_in.head()
p=plt.hist(data_in.sepal_length)
g=sns.pairplot(data_in)
sns.set(style='ticks',color_codes=True)
g=sns.pairplot(iris,hue='species')
g=sns.pairplot(iris,kind="reg",hue='species',vars=['sepal_length','petal_width'])
g=sns.pairplot(iris,kind='hist',hue='species')
g=sns.pairplot(iris,kind='kde',hue='species',vars=['sepal_width','petal_length'])
g=sns.pairplot(iris,kind='scatter',hue='species')
# Out:
# First five rows:
#    sepal.length  sepal.width  petal.length  petal.width  variety
# 0  sepal.length  sepal.width  petal.length  petal.width  variety
# 1           5.1          3.5           1.4           .2   Setosa
# 2           4.9            3           1.4           .2   Setosa
# 3           4.7          3.2           1.3           .2   Setosa
# 4           4.6          3.1           1.5           .2   Setosa
# Last five rows:
#     sepal.length sepal.width petal.length petal.width    variety
# 146          6.7           3          5.2         2.3  Virginica
# 147          6.3         2.5            5         1.9  Virginica
# 148          6.5           3          5.2           2  Virginica
# 149          6.2         3.4          5.4         2.3  Virginica
# 150          5.9           3          5.1         1.8  Virginica
# columns
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')
# size
# 755
# shape
# (151, 5)
# ...
