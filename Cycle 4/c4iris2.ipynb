# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
#3.
iris=sns.load_dataset('iris')
d=pd.DataFrame(iris)
d.head()
#displot
sns.displot(data=iris,kde=True,bins=5)

# %%
#histplot
sns.histplot(data=iris,kde=True,bins=7)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
#relplot
sns.relplot(data=iris)
